# %%
# !pip install simpy
# Out:
# Collecting simpy
#   Downloading simpy-4.1.1-py3-none-any.whl.metadata (6.1 kB)
# Downloading simpy-4.1.1-py3-none-any.whl (27 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.1.1

# %%
"""
Simple simulation of several bike rental stations

Stations are modeled with containers so bikes can be returned
to a station different from where it was rented from

programer:  Michael R. Gibbs
"""

import simpy
import random
import csv
import os, sys

# scenario attributes
station_names = ['A','B']
rent_probs = [.9,.1]
return_probs = [.5,.5]
bikes_per_station = 5


# def check_header(csvfile):
#   """Checks if a header already exists in a CSV file.

#   Args:
#     csv_file: The path to the CSV file.

#   Returns:
#     True if the header exists, False otherwise.
#   """

#   with open(csvfile, 'r') as f:
#     reader = csv.reader(f)
#     header = next(reader)

#   return header is not None

def rent_proc(env, id, station_names, rent_probs, return_probs, station_map):
    """
    Models the process of:
    selecting a station
    renting a bike
    using a bike
    returning a bike (can be different station)
    """

    #select a station
    csv_file = 'event_generator.csv'

    file_exists = os.path.isfile(csv_file)

    with open('event_generator.csv', 'a', newline='') as csvfile:
        
        name = random.choices(station_names,weights=rent_probs)
        name = name[0]
        station = station_map[name]

        print(f'{env.now}: id:{id} has arrived at station {name} q-len:{len(station.get_queue)} and {station.level} bikes')
        # row_data = [env.now, id, 'has arrived at station', name, len(station.get_queue), str(station.level)+' bikes']
        arrived_event = {'env': env.now, 'id' : id, 'event' : 'has arrived at station ', 'station' : name, 'q_len' : len(station.get_queue),
                   'bike_count' : str(station.level)+' bikes'}

        # Create a CSV writer object
        # writer = csv.writer(csvfile)
        writer = csv.DictWriter(csvfile, fieldnames=['env', 'id', 'event', 'station', 'q_len', 'bike_count'])

        # Write the header row
        # if not check_header(csvfile):
        # writer.writerow(header_data)
        if not file_exists:
            writer.writeheader()

        # Write the rows of data
        writer.writerow(arrived_event)

        # get a bike
        yield station.get(1)

        print(f'{env.now}: id:{id} has rented bike at station {name} q-len:{len(station.get_queue)} and {station.level} bikes')
        rented_event = {'env': env.now, 'id' : id, 'event' : 'has rented bike at station ', 'station' : name, 'q_len' : len(station.get_queue),
                   'bike_count' : str(station.level)+' bikes'}

        writer.writerow(rented_event)
        
        

        # use bike
        yield env.timeout(random.triangular(1,5,3))

        # return bike
        name = random.choices(station_names,weights=return_probs)
        name = name[0]
        station = station_map[name]

        yield station.put(1)

        print(f'{env.now}: id:{id} has returned bike at station {name} q-len:{len(station.get_queue)} and {station.level} bikes')

        returned_event = {'env': env.now, 'id' : id, 'event' : 'has returned bike at station ', 'station' : name, 'q_len' : len(station.get_queue),
                   'bike_count' : str(station.level)+' bikes'}

        writer.writerow(returned_event)

    csvfile.close()

def gen_arrivals(env, station_names, rent_probs, return_probs, station_map):
    """
    Generates arrivales to the rental stations
    """

    cnt = 0

    while True:
        yield env.timeout(random.expovariate(2.5))
        cnt += 1
        env.process(rent_proc(env,cnt,station_names,rent_probs,return_probs, station_map))

# set up
env = simpy.Environment()

# create station based on name list
cap = len(station_names) * bikes_per_station
station_map = {
    name: simpy.Container(env, init=bikes_per_station, capacity=cap)
    for name in station_names
}

# start generation arrivals
env.process(gen_arrivals(env, station_names, rent_probs, return_probs, station_map))

# start sim
env.run(100)
# Out:
# 0.6916729882282272: id:1 has arrived at station A q-len:0 and 5 bikes
# 0.6916729882282272: id:1 has rented bike at station A q-len:0 and 4 bikes
# 0.8868081266711825: id:2 has arrived at station A q-len:0 and 4 bikes
# 0.8868081266711825: id:2 has rented bike at station A q-len:0 and 3 bikes
# 1.2587592806860033: id:3 has arrived at station A q-len:0 and 3 bikes
# 1.2587592806860033: id:3 has rented bike at station A q-len:0 and 2 bikes
# 1.4880963002078595: id:4 has arrived at station A q-len:0 and 2 bikes
# 1.4880963002078595: id:4 has rented bike at station A q-len:0 and 1 bikes
# 2.1696672870741116: id:2 has returned bike at station B q-len:0 and 6 bikes
# 2.208980371369358: id:5 has arrived at station A q-len:0 and 1 bikes
# 2.208980371369358: id:5 has rented bike at station A q-len:0 and 0 bikes
# 2.2097248136478833: id:6 has arrived at station A q-len:0 and 0 bikes
# 2.24690293698876: id:7 has arrived at station A q-len:1 and 0 bikes
# 2.3666996624387426: id:8 has arrived at station B q-len:0 and 6 bikes
# 2.3666996624387426: id:8 has rented bike at station B q-len:0 and 5 bikes
# 2.5996221089887572: id:9 has arrived at station A q-len:2 and 0 bikes
# 3.0933897442834337: id:1 has returned bike at station A q-len:2 and 0 bikes
# 3.0933897442834337: id:6 has rented bike at station A q-len:2 and 0 bikes
# 3.552255736728791: id:3 has returned bike at station A q-len:1 and 0 bikes
# 3.552255736728791: id:7 has rented bike at station A q-len:1 and 0 bikes
# 3.6693578648665675: id:10 has arrived at station A q-len:1 and 0 bikes
# 3.9628931496172295: id:4 has returned bike at station B q-len:0 and 6 bikes
# 4.161714442598724: id:11 has arrived at station A q-len:2 and 0 bikes
# 4.172301339315068: id:12 has arrived at station A q-len:3 and 0 bikes
# 4.377019775998317: id:8 has returned bike at station B q-len:0 and 7 bikes
# 4.519925149734776: id:5 has returned bike at station A q-len:3 and 0 bikes
# 4.519925149734776: id:9 has rented bike at station A q-len:3 and 0 bikes
# 4.5936450248970635: id:13 has arrived at station A q-len:3 and 0 bikes
# 4.94754708805236: id:14 has arrived at station A q-len:4 and 0 bikes
# 5.584470567580885: id:7 has returned bike at station B q-len:0 and 8 bikes
# 5.772669658314634: id:15 has arrived at station A q-len:5 and 0 bikes
# 5.880989346314318: id:16 has arrived at station A q-len:6 and 0 bikes
# 6.101272503424122: id:6 has returned bike at station A q-len:6 and 0 bikes
# 6.101272503424122: id:10 has rented bike at station A q-len:6 and 0 bikes
# 6.339625681709815: id:17 has arrived at station A q-len:6 and 0 bikes
# 6.794028542153595: id:18 has arrived at station A q-len:7 and 0 bikes
# 6.972250646195853: id:19 has arrived at station A q-len:8 and 0 bikes
# 7.0099636453951835: id:9 has returned bike at station A q-len:8 and 0 bikes
# 7.0099636453951835: id:11 has rented bike at station A q-len:8 and 0 bikes
# 7.069309043361458: id:20 has arrived at station A q-len:8 and 0 bikes
# 7.172902723221643: id:21 has arrived at station A q-len:9 and 0 bikes
# 7.1971470142187375: id:10 has returned bike at station A q-len:9 and 0 bikes
# 7.1971470142187375: id:12 has rented bike at station A q-len:9 and 0 bikes
# 7.212717163137783: id:22 has arrived at station A q-len:9 and 0 bikes
# 7.395212095717222: id:23 has arrived at station A q-len:10 and 0 bikes
# 7.813441614573172: id:24 has arrived at station A q-len:11 and 0 bikes
# 8.43159021346653: id:25 has arrived at station B q-len:0 and 8 bikes
# 8.43159021346653: id:25 has rented bike at station B q-len:0 and 7 bikes
# 9.45370512126934: id:26 has arrived at station A q-len:12 and 0 bikes
# 9.459744608198045: id:27 has arrived at station B q-len:0 and 7 bikes
# 9.459744608198045: id:27 has rented bike at station B q-len:0 and 6 bikes
# 9.689878680400268: id:28 has arrived at station B q-len:0 and 6 bikes
# 9.689878680400268: id:28 has rented bike at station B q-len:0 and 5 bikes
# 10.209506787802296: id:11 has returned bike at station A q-len:12 and 0 bikes
# 10.209506787802296: id:13 has rented bike at station A q-len:12 and 0 bikes
# 10.246765432547758: id:12 has returned bike at station B q-len:0 and 6 bikes
# 10.998278989681783: id:25 has returned bike at station A q-len:11 and 0 bikes
# 10.998278989681783: id:14 has rented bike at station A q-len:11 and 0 bikes
# 11.079026476521149: id:27 has returned bike at station B q-len:0 and 7 bikes
# 11.802328122122573: id:29 has arrived at station B q-len:0 and 7 bikes
# 11.802328122122573: id:29 has rented bike at station B q-len:0 and 6 bikes
# 12.234831611131762: id:30 has arrived at station A q-len:11 and 0 bikes
# 12.326254579098709: id:28 has returned bike at station B q-len:0 and 7 bikes
# 12.386547491016115: id:31 has arrived at station B q-len:0 and 7 bikes
# 12.386547491016115: id:31 has rented bike at station B q-len:0 and 6 bikes
# 12.519985699931867: id:32 has arrived at station A q-len:12 and 0 bikes
# 12.686993558362419: id:33 has arrived at station A q-len:13 and 0 bikes
# 12.733479029111503: id:34 has arrived at station A q-len:14 and 0 bikes
# 12.967421496231179: id:35 has arrived at station A q-len:15 and 0 bikes
# 12.975061625520889: id:13 has returned bike at station B q-len:0 and 7 bikes
# 13.281613028388662: id:36 has arrived at station A q-len:16 and 0 bikes
# 13.349649115077792: id:37 has arrived at station A q-len:17 and 0 bikes
# 14.210618129555234: id:38 has arrived at station A q-len:18 and 0 bikes
# 14.38814611067496: id:39 has arrived at station A q-len:19 and 0 bikes
# 14.457058674363577: id:40 has arrived at station A q-len:20 and 0 bikes
# 14.675752758935511: id:41 has arrived at station A q-len:21 and 0 bikes
# 14.714760217832653: id:42 has arrived at station A q-len:22 and 0 bikes
# 14.862927706848405: id:14 has returned bike at station A q-len:22 and 0 bikes
# 14.862927706848405: id:15 has rented bike at station A q-len:22 and 0 bikes
# 15.005060121779692: id:43 has arrived at station A q-len:22 and 0 bikes
# 15.208775773747352: id:44 has arrived at station A q-len:23 and 0 bikes
# 15.2681749098844: id:45 has arrived at station B q-len:0 and 7 bikes
# 15.2681749098844: id:45 has rented bike at station B q-len:0 and 6 bikes
# 15.458050662428315: id:46 has arrived at station A q-len:24 and 0 bikes
# 15.49156416120494: id:47 has arrived at station A q-len:25 and 0 bikes
# 15.67053404706688: id:48 has arrived at station A q-len:26 and 0 bikes
# 16.001883691599254: id:49 has arrived at station B q-len:0 and 6 bikes
# 16.001883691599254: id:49 has rented bike at station B q-len:0 and 5 bikes
# 16.02734508622812: id:50 has arrived at station B q-len:0 and 5 bikes
# 16.02734508622812: id:50 has rented bike at station B q-len:0 and 4 bikes
# 16.051669826308174: id:29 has returned bike at station B q-len:0 and 5 bikes
# 16.180343211334357: id:51 has arrived at station A q-len:27 and 0 bikes
# 16.627295024708257: id:31 has returned bike at station A q-len:27 and 0 bikes
# 16.627295024708257: id:16 has rented bike at station A q-len:27 and 0 bikes
# 17.749242075927082: id:52 has arrived at station A q-len:27 and 0 bikes
# 17.872611256104936: id:45 has returned bike at station A q-len:27 and 0 bikes
# 17.872611256104936: id:17 has rented bike at station A q-len:27 and 0 bikes
# 18.472716319602632: id:53 has arrived at station A q-len:27 and 0 bikes
# 18.51432719824902: id:15 has returned bike at station A q-len:27 and 0 bikes
# 18.51432719824902: id:18 has rented bike at station A q-len:27 and 0 bikes
# 18.59310952276308: id:54 has arrived at station A q-len:27 and 0 bikes
# 18.718724867142353: id:50 has returned bike at station A q-len:27 and 0 bikes
# 18.718724867142353: id:19 has rented bike at station A q-len:27 and 0 bikes
# 19.31893714894021: id:49 has returned bike at station A q-len:26 and 0 bikes
# 19.31893714894021: id:20 has rented bike at station A q-len:26 and 0 bikes
# 19.56951877528288: id:55 has arrived at station A q-len:26 and 0 bikes
# 19.577068153675583: id:56 has arrived at station A q-len:27 and 0 bikes
# 19.699896137506332: id:57 has arrived at station A q-len:28 and 0 bikes
# 19.734232553825578: id:58 has arrived at station A q-len:29 and 0 bikes
# 20.49367150818327: id:59 has arrived at station B q-len:0 and 5 bikes
# 20.49367150818327: id:59 has rented bike at station B q-len:0 and 4 bikes
# 20.564459190279607: id:60 has arrived at station A q-len:30 and 0 bikes
# 20.792163181371055: id:16 has returned bike at station A q-len:30 and 0 bikes
# 20.792163181371055: id:21 has rented bike at station A q-len:30 and 0 bikes
# 20.961780646951386: id:17 has returned bike at station B q-len:0 and 5 bikes
# 21.193156386499084: id:61 has arrived at station A q-len:30 and 0 bikes
# 21.555861248282586: id:62 has arrived at station A q-len:31 and 0 bikes
# 21.84185515495541: id:18 has returned bike at station A q-len:31 and 0 bikes
# 21.84185515495541: id:22 has rented bike at station A q-len:31 and 0 bikes
# 22.019870738079625: id:20 has returned bike at station A q-len:30 and 0 bikes
# 22.019870738079625: id:23 has rented bike at station A q-len:30 and 0 bikes
# 22.196176938246154: id:19 has returned bike at station A q-len:29 and 0 bikes
# 22.196176938246154: id:24 has rented bike at station A q-len:29 and 0 bikes
# 23.553380751524124: id:22 has returned bike at station A q-len:28 and 0 bikes
# 23.553380751524124: id:26 has rented bike at station A q-len:28 and 0 bikes
# 23.707921054376833: id:21 has returned bike at station B q-len:0 and 6 bikes
# 23.743180542826522: id:59 has returned bike at station A q-len:27 and 0 bikes
# 23.743180542826522: id:30 has rented bike at station A q-len:27 and 0 bikes
# 23.89619981887316: id:63 has arrived at station A q-len:27 and 0 bikes
# 24.652263421496897: id:23 has returned bike at station A q-len:27 and 0 bikes
# 24.652263421496897: id:32 has rented bike at station A q-len:27 and 0 bikes
# 24.72747651800128: id:64 has arrived at station A q-len:27 and 0 bikes
# 25.300686833862926: id:65 has arrived at station B q-len:0 and 6 bikes
# 25.300686833862926: id:65 has rented bike at station B q-len:0 and 5 bikes
# 25.35108749664026: id:24 has returned bike at station B q-len:0 and 6 bikes
# 26.438558651989677: id:66 has arrived at station A q-len:28 and 0 bikes
# 26.881843454713724: id:26 has returned bike at station B q-len:0 and 7 bikes
# 26.921818418066167: id:32 has returned bike at station B q-len:0 and 8 bikes
# 27.027418046108977: id:67 has arrived at station A q-len:29 and 0 bikes
# 27.09570237765423: id:65 has returned bike at station B q-len:0 and 9 bikes
# 27.537214524076223: id:68 has arrived at station A q-len:30 and 0 bikes
# 27.553158857144194: id:69 has arrived at station A q-len:31 and 0 bikes
# 27.586021184091308: id:30 has returned bike at station B q-len:0 and 10 bikes
# 27.620806760945683: id:70 has arrived at station A q-len:32 and 0 bikes
# 28.213011891554178: id:71 has arrived at station A q-len:33 and 0 bikes
# 28.245101941492052: id:72 has arrived at station A q-len:34 and 0 bikes
# 28.43786242174056: id:73 has arrived at station A q-len:35 and 0 bikes
# 29.494560950178055: id:74 has arrived at station A q-len:36 and 0 bikes
# 29.52523599167079: id:75 has arrived at station A q-len:37 and 0 bikes
# 29.737231458267146: id:76 has arrived at station A q-len:38 and 0 bikes
# 29.940385843386224: id:77 has arrived at station A q-len:39 and 0 bikes
# 30.289201679973825: id:78 has arrived at station A q-len:40 and 0 bikes
# 30.527043836521518: id:79 has arrived at station A q-len:41 and 0 bikes
# 30.811324338871742: id:80 has arrived at station B q-len:0 and 10 bikes
# 30.811324338871742: id:80 has rented bike at station B q-len:0 and 9 bikes
# 31.409664763046557: id:81 has arrived at station A q-len:42 and 0 bikes
# 32.75983189637281: id:82 has arrived at station A q-len:43 and 0 bikes
# 32.763735982549825: id:80 has returned bike at station A q-len:43 and 0 bikes
# 32.763735982549825: id:33 has rented bike at station A q-len:43 and 0 bikes
# 32.81273593312594: id:83 has arrived at station A q-len:43 and 0 bikes
# 33.078596270423375: id:84 has arrived at station A q-len:44 and 0 bikes
# 33.28683018936602: id:85 has arrived at station A q-len:45 and 0 bikes
# 34.14173318362351: id:86 has arrived at station A q-len:46 and 0 bikes
# 34.37052926808413: id:87 has arrived at station B q-len:0 and 9 bikes
# 34.37052926808413: id:87 has rented bike at station B q-len:0 and 8 bikes
# 34.868516463437906: id:88 has arrived at station A q-len:47 and 0 bikes
# 35.28023940469801: id:89 has arrived at station A q-len:48 and 0 bikes
# 35.48044062758895: id:90 has arrived at station A q-len:49 and 0 bikes
# 35.63449129607294: id:33 has returned bike at station A q-len:49 and 0 bikes
# 35.63449129607294: id:34 has rented bike at station A q-len:49 and 0 bikes
# 35.74111951609676: id:91 has arrived at station B q-len:0 and 8 bikes
# 35.74111951609676: id:91 has rented bike at station B q-len:0 and 7 bikes
# 36.30910586468388: id:92 has arrived at station A q-len:49 and 0 bikes
# 36.42178928677565: id:93 has arrived at station A q-len:50 and 0 bikes
# 37.04072048107505: id:94 has arrived at station A q-len:51 and 0 bikes
# 37.72334471029424: id:95 has arrived at station A q-len:52 and 0 bikes
# 37.75566100544513: id:87 has returned bike at station B q-len:0 and 8 bikes
# 37.86941658391641: id:96 has arrived at station A q-len:53 and 0 bikes
# 38.05106390709693: id:97 has arrived at station A q-len:54 and 0 bikes
# 38.475487216612: id:98 has arrived at station A q-len:55 and 0 bikes
# 39.396755892257254: id:34 has returned bike at station B q-len:0 and 9 bikes
# 39.482605698720036: id:91 has returned bike at station B q-len:0 and 10 bikes
# 40.24575008560877: id:99 has arrived at station B q-len:0 and 10 bikes
# 40.24575008560877: id:99 has rented bike at station B q-len:0 and 9 bikes
# 40.300220045073715: id:100 has arrived at station A q-len:56 and 0 bikes
# 40.742878985273286: id:101 has arrived at station A q-len:57 and 0 bikes
# 40.80131231659651: id:102 has arrived at station A q-len:58 and 0 bikes
# 41.691092187477366: id:103 has arrived at station A q-len:59 and 0 bikes
# 41.8331999143946: id:104 has arrived at station A q-len:60 and 0 bikes
# 41.83618054195217: id:105 has arrived at station A q-len:61 and 0 bikes
# 42.04327064264454: id:99 has returned bike at station B q-len:0 and 10 bikes
# 42.155247432444355: id:106 has arrived at station A q-len:62 and 0 bikes
# 42.667481398338445: id:107 has arrived at station A q-len:63 and 0 bikes
# 43.22399775273927: id:108 has arrived at station A q-len:64 and 0 bikes
# 44.78668465845465: id:109 has arrived at station A q-len:65 and 0 bikes
# 45.64787989300909: id:110 has arrived at station A q-len:66 and 0 bikes
# 45.66063273272435: id:111 has arrived at station A q-len:67 and 0 bikes
# 45.85110185014057: id:112 has arrived at station A q-len:68 and 0 bikes
# 46.23813077422657: id:113 has arrived at station A q-len:69 and 0 bikes
# 47.283066281283205: id:114 has arrived at station A q-len:70 and 0 bikes
# 47.81720685833243: id:115 has arrived at station A q-len:71 and 0 bikes
# 48.07019698391447: id:116 has arrived at station A q-len:72 and 0 bikes
# 48.43423284812815: id:117 has arrived at station A q-len:73 and 0 bikes
# 48.63584616693816: id:118 has arrived at station A q-len:74 and 0 bikes
# 48.75895070118738: id:119 has arrived at station A q-len:75 and 0 bikes
# 48.84040335241686: id:120 has arrived at station A q-len:76 and 0 bikes
# 48.88446698187968: id:121 has arrived at station A q-len:77 and 0 bikes
# 49.5854865791455: id:122 has arrived at station A q-len:78 and 0 bikes
# 49.951846489050695: id:123 has arrived at station B q-len:0 and 10 bikes
# 49.951846489050695: id:123 has rented bike at station B q-len:0 and 9 bikes
# 50.038899690971604: id:124 has arrived at station A q-len:79 and 0 bikes
# 50.193249614809005: id:125 has arrived at station A q-len:80 and 0 bikes
# 50.54410123258146: id:126 has arrived at station A q-len:81 and 0 bikes
# 50.707343663917605: id:127 has arrived at station A q-len:82 and 0 bikes
# 50.802566457798854: id:128 has arrived at station A q-len:83 and 0 bikes
# 51.04904708019555: id:129 has arrived at station A q-len:84 and 0 bikes
# 52.4458577326031: id:130 has arrived at station A q-len:85 and 0 bikes
# 52.77697359593672: id:131 has arrived at station A q-len:86 and 0 bikes
# 53.25337024205428: id:132 has arrived at station A q-len:87 and 0 bikes
# 53.508360373282436: id:133 has arrived at station A q-len:88 and 0 bikes
# 53.73288170221172: id:134 has arrived at station A q-len:89 and 0 bikes
# 54.127715426234: id:135 has arrived at station A q-len:90 and 0 bikes
# 54.38967485078142: id:136 has arrived at station A q-len:91 and 0 bikes
# 54.42599462160739: id:123 has returned bike at station A q-len:91 and 0 bikes
# 54.42599462160739: id:35 has rented bike at station A q-len:91 and 0 bikes
# 54.563501877003816: id:137 has arrived at station A q-len:91 and 0 bikes
# 54.604458755170185: id:138 has arrived at station A q-len:92 and 0 bikes
# 54.845537601018776: id:139 has arrived at station A q-len:93 and 0 bikes
# 56.25872208973743: id:140 has arrived at station A q-len:94 and 0 bikes
# 56.784130108491205: id:35 has returned bike at station A q-len:94 and 0 bikes
# 56.784130108491205: id:36 has rented bike at station A q-len:94 and 0 bikes
# 57.16028379105585: id:141 has arrived at station A q-len:94 and 0 bikes
# 57.55240635456828: id:142 has arrived at station A q-len:95 and 0 bikes
# 57.931983238362285: id:143 has arrived at station B q-len:0 and 9 bikes
# 57.931983238362285: id:143 has rented bike at station B q-len:0 and 8 bikes
# 58.10448812459841: id:144 has arrived at station A q-len:96 and 0 bikes
# 58.405837769291914: id:145 has arrived at station B q-len:0 and 8 bikes
# 58.405837769291914: id:145 has rented bike at station B q-len:0 and 7 bikes
# 58.56013765488564: id:146 has arrived at station A q-len:97 and 0 bikes
# 58.89567134203791: id:147 has arrived at station A q-len:98 and 0 bikes
# 59.213617886276865: id:148 has arrived at station A q-len:99 and 0 bikes
# 59.68908668243249: id:36 has returned bike at station A q-len:99 and 0 bikes
# 59.68908668243249: id:37 has rented bike at station A q-len:99 and 0 bikes
# 61.173602275520615: id:149 has arrived at station A q-len:99 and 0 bikes
# 61.30800421200403: id:143 has returned bike at station B q-len:0 and 8 bikes
# 61.503880172958084: id:150 has arrived at station A q-len:100 and 0 bikes
# 61.73192054705689: id:151 has arrived at station A q-len:101 and 0 bikes
# 61.97040638598865: id:145 has returned bike at station B q-len:0 and 9 bikes
# 62.148621815325875: id:152 has arrived at station A q-len:102 and 0 bikes
# 62.25737351912273: id:153 has arrived at station A q-len:103 and 0 bikes
# 62.43111863761025: id:37 has returned bike at station A q-len:103 and 0 bikes
# 62.43111863761025: id:38 has rented bike at station A q-len:103 and 0 bikes
# 62.56847317669564: id:154 has arrived at station A q-len:103 and 0 bikes
# 62.874473722086776: id:155 has arrived at station B q-len:0 and 9 bikes
# 62.874473722086776: id:155 has rented bike at station B q-len:0 and 8 bikes
# 62.9771313431063: id:156 has arrived at station A q-len:104 and 0 bikes
# 63.471241923771885: id:157 has arrived at station A q-len:105 and 0 bikes
# 63.58823464067317: id:158 has arrived at station A q-len:106 and 0 bikes
# 63.801643721164: id:159 has arrived at station A q-len:107 and 0 bikes
# 64.1268191960607: id:160 has arrived at station A q-len:108 and 0 bikes
# 64.14724899855248: id:161 has arrived at station A q-len:109 and 0 bikes
# 64.1931293239402: id:162 has arrived at station A q-len:110 and 0 bikes
# 64.94702414418381: id:163 has arrived at station B q-len:0 and 8 bikes
# 64.94702414418381: id:163 has rented bike at station B q-len:0 and 7 bikes
# 65.01091818059616: id:164 has arrived at station A q-len:111 and 0 bikes
# 66.26733526972318: id:155 has returned bike at station B q-len:0 and 8 bikes
# 66.61256326925596: id:38 has returned bike at station A q-len:111 and 0 bikes
# 66.61256326925596: id:39 has rented bike at station A q-len:111 and 0 bikes
# 66.64810975892036: id:165 has arrived at station A q-len:111 and 0 bikes
# 67.31309368598657: id:166 has arrived at station A q-len:112 and 0 bikes
# 67.9721353505394: id:163 has returned bike at station A q-len:112 and 0 bikes
# 67.9721353505394: id:40 has rented bike at station A q-len:112 and 0 bikes
# 68.07932935531304: id:167 has arrived at station A q-len:112 and 0 bikes
# 68.52326357151395: id:168 has arrived at station A q-len:113 and 0 bikes
# 68.85928208662055: id:39 has returned bike at station B q-len:0 and 9 bikes
# 69.30158437820516: id:40 has returned bike at station B q-len:0 and 10 bikes
# 69.30794769461878: id:169 has arrived at station A q-len:114 and 0 bikes
# 70.95574835653177: id:170 has arrived at station A q-len:115 and 0 bikes
# 71.3482157431424: id:171 has arrived at station A q-len:116 and 0 bikes
# 71.39915595698714: id:172 has arrived at station A q-len:117 and 0 bikes
# 71.67209474163612: id:173 has arrived at station A q-len:118 and 0 bikes
# 72.08581360324565: id:174 has arrived at station A q-len:119 and 0 bikes
# 72.33346450374275: id:175 has arrived at station B q-len:0 and 10 bikes
# 72.33346450374275: id:175 has rented bike at station B q-len:0 and 9 bikes
# 73.19076433722672: id:176 has arrived at station A q-len:120 and 0 bikes
# 74.40001117147602: id:177 has arrived at station A q-len:121 and 0 bikes
# 74.54709378279581: id:178 has arrived at station A q-len:122 and 0 bikes
# 75.06493450013238: id:179 has arrived at station A q-len:123 and 0 bikes
# 75.51583095146704: id:180 has arrived at station A q-len:124 and 0 bikes
# 75.56947015237743: id:181 has arrived at station A q-len:125 and 0 bikes
# 75.7424475517913: id:182 has arrived at station A q-len:126 and 0 bikes
# 75.74628610060441: id:175 has returned bike at station A q-len:126 and 0 bikes
# 75.74628610060441: id:41 has rented bike at station A q-len:126 and 0 bikes
# 76.34227648662151: id:183 has arrived at station A q-len:126 and 0 bikes
# 76.35404925529652: id:184 has arrived at station A q-len:127 and 0 bikes
# 77.65303602517048: id:185 has arrived at station A q-len:128 and 0 bikes
# 77.74701553520657: id:186 has arrived at station A q-len:129 and 0 bikes
# 78.06221374371536: id:187 has arrived at station A q-len:130 and 0 bikes
# 78.08492777940954: id:188 has arrived at station A q-len:131 and 0 bikes
# 78.11977964843031: id:189 has arrived at station A q-len:132 and 0 bikes
# 78.36012485247882: id:190 has arrived at station A q-len:133 and 0 bikes
# 78.47729481617579: id:191 has arrived at station A q-len:134 and 0 bikes
# 78.56430688992435: id:192 has arrived at station A q-len:135 and 0 bikes
# 78.81756159220325: id:193 has arrived at station A q-len:136 and 0 bikes
# 79.04766143469433: id:194 has arrived at station A q-len:137 and 0 bikes
# 79.467581429447: id:41 has returned bike at station B q-len:0 and 10 bikes
# 79.50824792696393: id:195 has arrived at station A q-len:138 and 0 bikes
# 79.5873877604509: id:196 has arrived at station A q-len:139 and 0 bikes
# 79.67462829438043: id:197 has arrived at station A q-len:140 and 0 bikes
# 80.21696299079234: id:198 has arrived at station A q-len:141 and 0 bikes
# 80.26410398122549: id:199 has arrived at station A q-len:142 and 0 bikes
# 80.35955588595013: id:200 has arrived at station A q-len:143 and 0 bikes
# 80.3924460302569: id:201 has arrived at station A q-len:144 and 0 bikes
# 80.47846901354657: id:202 has arrived at station B q-len:0 and 10 bikes
# 80.47846901354657: id:202 has rented bike at station B q-len:0 and 9 bikes
# 80.78312707823913: id:203 has arrived at station A q-len:145 and 0 bikes
# 81.21496080008622: id:204 has arrived at station A q-len:146 and 0 bikes
# 81.42373158251172: id:205 has arrived at station A q-len:147 and 0 bikes
# 82.99803459446865: id:206 has arrived at station A q-len:148 and 0 bikes
# 83.70116735930253: id:202 has returned bike at station A q-len:148 and 0 bikes
# 83.70116735930253: id:42 has rented bike at station A q-len:148 and 0 bikes
# 83.78142549047693: id:207 has arrived at station A q-len:148 and 0 bikes
# 84.19295294684018: id:208 has arrived at station A q-len:149 and 0 bikes
# 84.59573448088193: id:209 has arrived at station A q-len:150 and 0 bikes
# 85.51051912094103: id:210 has arrived at station A q-len:151 and 0 bikes
# 86.00166328543891: id:211 has arrived at station A q-len:152 and 0 bikes
# 86.54464905489262: id:212 has arrived at station A q-len:153 and 0 bikes
# 86.77099492195397: id:213 has arrived at station A q-len:154 and 0 bikes
# 86.9000870952976: id:214 has arrived at station A q-len:155 and 0 bikes
# 87.25544988646799: id:215 has arrived at station A q-len:156 and 0 bikes
# 87.373324602764: id:216 has arrived at station A q-len:157 and 0 bikes
# 87.45809975771134: id:42 has returned bike at station B q-len:0 and 10 bikes
# 87.79527999868328: id:217 has arrived at station A q-len:158 and 0 bikes
# 88.58105731898961: id:218 has arrived at station B q-len:0 and 10 bikes
# 88.58105731898961: id:218 has rented bike at station B q-len:0 and 9 bikes
# 88.73943476122811: id:219 has arrived at station A q-len:159 and 0 bikes
# 88.90205579871912: id:220 has arrived at station A q-len:160 and 0 bikes
# 89.16841935939266: id:221 has arrived at station A q-len:161 and 0 bikes
# 89.65970379060255: id:222 has arrived at station A q-len:162 and 0 bikes
# 90.10717950882359: id:223 has arrived at station A q-len:163 and 0 bikes
# 91.01446591709234: id:224 has arrived at station A q-len:164 and 0 bikes
# 91.36821440771791: id:218 has returned bike at station A q-len:164 and 0 bikes
# 91.36821440771791: id:43 has rented bike at station A q-len:164 and 0 bikes
# 91.62123618739341: id:225 has arrived at station A q-len:164 and 0 bikes
# 91.75550376095894: id:226 has arrived at station A q-len:165 and 0 bikes
# 91.87474840098947: id:227 has arrived at station A q-len:166 and 0 bikes
# 91.96050186026942: id:228 has arrived at station A q-len:167 and 0 bikes
# 93.08411944761491: id:229 has arrived at station A q-len:168 and 0 bikes
# 93.38498582769626: id:230 has arrived at station A q-len:169 and 0 bikes
# 93.42142686527052: id:231 has arrived at station A q-len:170 and 0 bikes
# 93.50811168962554: id:232 has arrived at station A q-len:171 and 0 bikes
# 93.8147966004491: id:233 has arrived at station A q-len:172 and 0 bikes
# 93.89311557723167: id:234 has arrived at station A q-len:173 and 0 bikes
# 94.25674540525605: id:235 has arrived at station A q-len:174 and 0 bikes
# 94.63662018951037: id:236 has arrived at station B q-len:0 and 9 bikes
# 94.63662018951037: id:236 has rented bike at station B q-len:0 and 8 bikes
# 95.47804639461575: id:43 has returned bike at station A q-len:174 and 0 bikes
# 95.47804639461575: id:44 has rented bike at station A q-len:174 and 0 bikes
# 95.76287403031886: id:237 has arrived at station A q-len:174 and 0 bikes
# 96.04759394076919: id:238 has arrived at station A q-len:175 and 0 bikes
# 96.2576557548275: id:239 has arrived at station B q-len:0 and 8 bikes
# 96.2576557548275: id:239 has rented bike at station B q-len:0 and 7 bikes
# 96.61571470945367: id:236 has returned bike at station B q-len:0 and 8 bikes
# 96.75378722949051: id:240 has arrived at station B q-len:0 and 8 bikes
# 96.75378722949051: id:240 has rented bike at station B q-len:0 and 7 bikes
# 97.07140636422201: id:241 has arrived at station A q-len:176 and 0 bikes
# 97.69222496148942: id:242 has arrived at station A q-len:177 and 0 bikes
# 97.81317358476981: id:243 has arrived at station A q-len:178 and 0 bikes
# 98.56677976637162: id:239 has returned bike at station A q-len:178 and 0 bikes
# 98.56677976637162: id:46 has rented bike at station A q-len:178 and 0 bikes
# 98.62401058553115: id:44 has returned bike at station A q-len:177 and 0 bikes
# 98.62401058553115: id:47 has rented bike at station A q-len:177 and 0 bikes
# 98.63301448256648: id:244 has arrived at station B q-len:0 and 7 bikes
# 98.63301448256648: id:244 has rented bike at station B q-len:0 and 6 bikes
# 98.76101122935414: id:240 has returned bike at station A q-len:176 and 0 bikes
# 98.76101122935414: id:48 has rented bike at station A q-len:176 and 0 bikes
# 98.99803234083573: id:245 has arrived at station A q-len:176 and 0 bikes
# 99.2424992127341: id:246 has arrived at station A q-len:177 and 0 bikes
# 99.45782764654845: id:247 has arrived at station A q-len:178 and 0 bikes
# 99.97967669366605: id:248 has arrived at station A q-len:179 and 0 bikes
